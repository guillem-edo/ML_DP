# %% [markdown]
# # 1.Importamos librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from yellowbrick.cluster import KElbowVisualizer

# %% [markdown]
# # 2.Importamos datos

# %%
# Leer los datos del archivo csv
# Tu Código
original = pd.read_csv('winequality_kmeans.csv', sep = ';')
df = original.copy()

# Visualizar las primeras filas del conjunto de datos
# Tu Código
df.sample(10)
# Out:
#       4fixed acidity  volatile acidity  citric acid  residual sugar  \
# 1541       -0.413324          0.123866    -0.313015       -0.240300
# 406        -0.241019          0.068019     0.354333       -0.027523
# 1368        0.505637          0.291408    -0.364349        0.327105
# 52          0.907683         -0.155370     1.175683        7.987070
# 287        -0.241019         -1.160621     1.227017       -0.524002
# 594         1.079988         -0.937232     1.894365        0.256179
# 1565        0.965118         -0.825538     0.559670       -0.665853
# 751         1.252293         -1.607400     1.021680       -0.311225
# 306         0.333332         -0.546301     0.919011       -0.453077
# 1590       -0.011279          0.989499    -0.775024        0.043403
#
#       chlorides  free sulfur dioxide  total sulfur dioxide   density  \
# 1541  -0.349866            -0.848450             -0.561411 -0.183687
# 406   -0.243630            -0.752849             -0.895805 -2.329571
# 1368  -0.137395            -0.083643              2.083342  0.664069
# 52     2.497242             3.071185              1.080160  3.005997
# 287    5.386844             0.107558              0.289774  0.081237
# 594    0.733735            -0.561648             -0.166218  0.664069
# 1565   1.732348             1.063567              1.323355  1.268096
# 751   -0.456101            -0.944051             -0.683009  0.558100
# 306   -0.753560            -0.944051             -0.926204 -1.031444
# 1590   0.096323            -0.370446             -0.561411  1.405857
#
#             pH  sulphates   alcohol  DO
# 1541 -0.201528  -0.638020 -0.678432   1
# 406  -0.719708   0.364889  2.512056   0
# 1368 -0.525391  -0.402042 -0.866108   3
# 52   -0.978798   0.541872 -1.522973   3
# 287  -1.756068   2.488695 -1.147622   2
# 594  -0.525391   0.010921  1.949029   2
# 1565 -1.043571  -0.048074 -1.804487   3
# 751  -1.043571   1.426792  0.541460   2
# 306   0.251880   0.246899  1.949029   0
# 1590  1.288240   0.364889 -0.396918   1

# %%
# No necesitamos la columna 'DO' para el clustering- Eliminarla y trabajar con el resto de columnas
# pero guardar el data frame original en df_fin
# Tu Código
df.drop(['DO'], inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 4
#       1 # No necesitamos la columna 'DO' para el clustering- Eliminarla y trabajar con el resto de columnas
#       2 # pero guardar el data frame original en df_fin
#       3 # Tu Código
# ----> 4 df.drop(['DO'], inplace = True)
#
# File c:\Users\GuillemEdoBertran\.conda\envs\ML_IMPELIA\lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File c:\Users\GuillemEdoBertran\.conda\envs\ML_IMPELIA\lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File c:\Users\GuillemEdoBertran\.conda\envs\ML_IMPELIA\lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File c:\Users\GuillemEdoBertran\.conda\envs\ML_IMPELIA\lib\site-packages\pandas\core\indexes\base.py:7000, in Index.drop(self, labels, errors)
#    6998 if mask.any():
#    6999     if errors != "ignore":
# -> 7000         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001     indexer = indexer[~mask]
#    7002 return self.delete(indexer)
#
# KeyError: "['DO'] not found in axis"

# %% [markdown]
# # 3.Preprocesado (en este caso solo estandarizar)

# %%
# Escalamos todo el data frame y lo guardamos en df_std
# Tu Código

# %% [markdown]
# # 4.Crear el modelo y los grupos

# %%
# Primero con 3 grupos. Guardar los grupos en la variable 'clusters'
# Tu Código
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# Mostrar los centros de los clysters creados
# Tu Código

# %% [markdown]
# # 5.Asignar el número de grupo a cada fila

# %%
# Agregar la columna de clusters al DataFrame original
# Tu Código

# %% [markdown]
# # 6.Dibujar los daos según dos variables que seleccionemos añadiendo el grupo (cluster) en el color

# %%
plt.figure(figsize=(10, 6))
for cluster in range(numero_clusters):
    cluster_data = df[df['Cluster'] == cluster]
    plt.scatter(cluster_data['alcohol'], cluster_data['pH'], label=f'Cluster {cluster}')
plt.scatter(kmeans.cluster_centers_[:, 9], kmeans.cluster_centers_[:, 8], s=200, c='black', marker='X', label='Centroids')

plt.title('Clusters de Vinos')
plt.xlabel('Alcohol')
plt.ylabel('pH')
plt.legend()
plt.show()

# %% [markdown]
# # 7.Obtener el número óptimo de grupos

# %%
# Obtención del número óptimo de clústers
# librería yellowbrick que proporciona herramientas visuales para la selección de modelos, incluido el método de Elbow.

# Utiliza la visualización de codo para encontrar el número óptimo de clusters. Usar n_init=10
model = KMeans(n_init = 10)
visualizer = KElbowVisualizer(model, k=(1, 10))
visualizer.fit(df_std)
visualizer.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# # 8.Modelo final (agrupación final). En este caso 4 grupos

# %%
# Número óptimo de clusters obtenido del gráfico del codo
# Asignar a la variable "optimal_clusters" el numero de clusteres para construir el modelo
# Tu Código

# Aplicar KMeans con el número óptimo de clusters (optimal_clusters)
# Asignar los clusteres obtenidos a la variable "clusters" después de haber realizado el fit_predict de KMeans
# Tu Código

# Agregar la columna de clusters al DataFrame original
# Tu Código

# %%
# Graficar los clusters en función de las características 'alcohol' y 'pH'
# Tu Código

# %% [markdown]
# # 9.Interpretación de los grupos

# %%
# Realizar la media por cada cluster de todas las variables

# Tu Código

# %% [markdown]
# # 10.Interpretación de los grupos CON VARIABLES EXTERNAS

# %%
# Añade la variable cluster al data frame original (que habíamos llamado df_fin)
# Tu Código

# %%
#Mira la tabla de frecuencia de la varoable DO para cada cluster#
# Tu Código
